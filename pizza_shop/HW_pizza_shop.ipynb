# %% [markdown]
# # Pizza Shop
# You work at a pizza restaurant, which is starting to accept orders online. You need to
# provide a python function that will accept an arbitrary order as its arguments,
# and compute the correct price for the order.
#
# Your cost-calculator function should have four arguments:
# - pizzas
# - drinks
# - wings
# - coupon
#
#
# A single pizza order is formed as a list of toppings. For example
# - A pizza with no toppings (other than cheese and sauce is: [] (an empty list)
# - A pizza with pepperoni and a double order of olives is : ["pepperoni", "olives", "olives"]
#
# *An arbitrary number of pizzas may be ordered, including no pizzas as all*
#
# Drinks come in as a named order (i.e. a keyword argument 'drinks'). If drinks are ordered,
# they are specified as a list of sizes (possible sizes: "small", "medium", "large", "tub"). For example, `drinks=["small", "small", "large"]` would indicate an order including two small drinks and a large drink.
#
# Wings come in as a named order as well (keyword argument 'wings'). If wings are ordered,
# they are specified as a list of integers (possible sizes: 10, 20, 40, 100). For example, `wings=[20]` would indicate a single order of 20-piece wings.
#
# A coupon may be specified as the keyword argument 'coupon'. It is will be a single
# floating point number between 0 and 1. This indicates the fraction of the *pre-tax*
# price that is to be subtracted. For example `coupon=.25` would indicate a 25%-off coupon.
#
# A 6.25% tax is applied to every order. The tax is computed on the total cost of the
# order *before a coupon is applied*
#
# Round the price to the nearest cent, using the built-in function round. `round(x, 2)` will round `x` to two decimal places.
#
# ## Prices
# The prices are as follows:
#
# **Pizza**
# - \$13.00
#
# **Toppings**
# - pepperoni : \$1.00
# - mushroom : \$0.50
# - olive : \$0.50
# - anchovy : \$2.00
# - ham : \$1.50
#
# **Drinks**
# - small : \$2.00
# - medium : \$3.00
# - large : \$3.50
# - tub : \$3.75
#
# **Wings**
# - 10 : \$5.00
# - 20 : \$9.00
# - 40 : \$17.50
# - 100 : \$48.00
#
#
# ## Examples
# The following is an order for a plain pizza, a ham and anchovy pizza, two "tub"-sized
# drinks, with a 10%-off coupon:
# ```python
# >>>cost_calculator([], ["ham", "anchovy"], drinks=["tub", "tub"], coupon=0.1)
# 35.61
# ```
#
# This order consists only of a small drink.
# ```python
# >>> cost_calculator(drinks=["small"])
# 2.12
# ```
#
# This is an order of two plain pizzas, a pizza with double-pepperoni, an order of a 10-piece and a 20-piece wings, and a small drink.
# ```python
# >>> cost_calculator([], [], ["pepperoni", "pepperoni"], wings=[10, 20], drinks=["small"])
# 60.56
# ```
#
# ## Details
# You can assume that the front-end of the website will never pass your function erroneous
# orders. That is, you will never receive orders for items that do not exist nor
# items that contain typos.
#
# Consider defining individual functions responsible for computing
# the cost of the pizzas, drinks, and wings, respectively. Have `cost_calculator`
# invoke these internally. Alternatively, you can read ahead about dictionaries and make nice
# use of these in this problem.
#
# Our `cost_calculator` signature is empty. Part of the assignment is to come up with the
# correct function signature!

# %%
# make sure to execute this cell so that your function is defined
# you must re-run this cell any time you make a change to this function


def pizza_cost(pizza):
    price = 13
    for x in pizza:
        if x == 'pepperoni':  price += 1.00
        if x == 'mushroom' : price += .50
        if x == 'olive' : price += .50
        if x == 'anchovy' : price += 2.00
        if x == 'ham': price += 1.50
    return price

def drinks_cost(drinks):
    if drinks == 'tub': return 3.75   
    if drinks == 'small' : return 2.00
    if drinks == 'medium' : return 3.00
    if drinks == 'large' : return 3.50

def wings_cost(wings):
    if wings == 100: return 48.00
    if wings == 40: return 17.50
    if wings == 20: return 9.00
    if wings == 10: return 5.00
    


def cost_calculator(*pizza, drinks=[], wings=[], coupon = 0.0):
    total_price = 0.0
    for x in pizza:
        print(x)
        pizza_price = pizza_cost(x)
        total_price += pizza_cost(x)
        print(pizza)
    
    if drinks:
        for drink in drinks:
            total_price += drinks_cost(drink)
    
    if wings:
        for wing in wings:
            total_price += wings_cost(wing)

    tax_cost = total_price * 0.0625
    coupon_bonus = total_price * coupon
    final_price = total_price - coupon_bonus + tax_cost
    print("-----")
    return round(final_price, 2)

# %%
# Execute this cell to grade your work
from bwsi_grader.python.pizza_shop import grader
grader(cost_calculator)
# Out:
# []
# ([],)
# -----
# -----
# ['pepperoni']
# (['pepperoni'], [])
# []
# (['pepperoni'], [])
# -----
# []
# ([], [])
# []
# ([], [])
# -----
# ['ham', 'olive', 'ham']
# (['ham', 'olive', 'ham'], ['anchovy'], ['olive', 'mushroom', 'ham'])
# ['anchovy']
# (['ham', 'olive', 'ham'], ['anchovy'], ['olive', 'mushroom', 'ham'])
# ['olive', 'mushroom', 'ham']
# (['ham', 'olive', 'ham'], ['anchovy'], ['olive', 'mushroom', 'ham'])
# -----
# ['olive', 'olive']
# (['olive', 'olive'],)
# -----
# ['olive', 'mushroom', 'pepperoni']
# (['olive', 'mushroom', 'pepperoni'],)
# -----
# ['mushroom', 'olive', 'mushroom']
# (['mushroom', 'olive', 'mushroom'], ['ham'], ['pepperoni'], [])
# ['ham']
# (['mushroom', 'olive', 'mushroom'], ['ham'], ['pepperoni'], [])
# ['pepperoni']
# (['mushroom', 'olive', 'mushroom'], ['ham'], ['pepperoni'], [])
# []
# (['mushroom', 'olive', 'mushroom'], ['ham'], ['pepperoni'], [])
# -----
# ['mushroom', 'mushroom', 'mushroom']
# (['mushroom', 'mushroom', 'mushroom'],)
# -----
# -----
# ['ham', 'pepperoni', 'ham']
# (['ham', 'pepperoni', 'ham'], ['mushroom'])
# ['mushroom']
# (['ham', 'pepperoni', 'ham'], ['mushroom'])
# -----
# []
# ([], ['pepperoni', 'anchovy'], ['pepperoni', 'anchovy'], [])
# ['pepperoni', 'anchovy']
# ([], ['pepperoni', 'anchovy'], ['pepperoni', 'anchovy'], [])
# ['pepperoni', 'anchovy']
# ([], ['pepperoni', 'anchovy'], ['pepperoni', 'anchovy'], [])
# []
# ([], ['pepperoni', 'anchovy'], ['pepperoni', 'anchovy'], [])
# -----
# ['pepperoni', 'mushroom', 'mushroom']
# (['pepperoni', 'mushroom', 'mushroom'], [], ['ham', 'anchovy'], ['olive'])
# []
# (['pepperoni', 'mushroom', 'mushroom'], [], ['ham', 'anchovy'], ['olive'])
# ['ham', 'anchovy']
# (['pepperoni', 'mushroom', 'mushroom'], [], ['ham', 'anchovy'], ['olive'])
# ['olive']
# (['pepperoni', 'mushroom', 'mushroom'], [], ['ham', 'anchovy'], ['olive'])
# -----
# []
# ([], ['olive', 'olive', 'olive'], ['mushroom'], [])
# ['olive', 'olive', 'olive']
# ([], ['olive', 'olive', 'olive'], ['mushroom'], [])
# ['mushroom']
# ([], ['olive', 'olive', 'olive'], ['mushroom'], [])
# []
# ([], ['olive', 'olive', 'olive'], ['mushroom'], [])
# -----
# ['mushroom']
# (['mushroom'],)
# -----
# ['olive']
# (['olive'],)
# -----
# ['olive']
# (['olive'],)
# -----
# -----
# ['pepperoni', 'anchovy']
# (['pepperoni', 'anchovy'],)
# -----
# ['anchovy']
# (['anchovy'], ['olive', 'ham'], ['pepperoni', 'mushroom', 'olive'], [])
# ['olive', 'ham']
# (['anchovy'], ['olive', 'ham'], ['pepperoni', 'mushroom', 'olive'], [])
# ['pepperoni', 'mushroom', 'olive']
# (['anchovy'], ['olive', 'ham'], ['pepperoni', 'mushroom', 'olive'], [])
# []
# (['anchovy'], ['olive', 'ham'], ['pepperoni', 'mushroom', 'olive'], [])
# -----
# ['ham', 'mushroom']
# (['ham', 'mushroom'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], [])
# ['mushroom', 'mushroom']
# (['ham', 'mushroom'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], [])
# ['pepperoni', 'olive']
# (['ham', 'mushroom'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], [])
# []
# (['ham', 'mushroom'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], [])
# -----
# ['pepperoni', 'ham', 'mushroom']
# (['pepperoni', 'ham', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['mushroom'], ['mushroom'])
# ['mushroom', 'olive', 'anchovy']
# (['pepperoni', 'ham', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['mushroom'], ['mushroom'])
# ['mushroom']
# (['pepperoni', 'ham', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['mushroom'], ['mushroom'])
# ['mushroom']
# (['pepperoni', 'ham', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['mushroom'], ['mushroom'])
# -----
# ['pepperoni', 'mushroom']
# (['pepperoni', 'mushroom'],)
# -----
# []
# ([],)
# -----
# ['olive']
# (['olive'], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], ['anchovy'])
# ['olive', 'ham', 'mushroom']
# (['olive'], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], ['anchovy'])
# ['ham', 'mushroom']
# (['olive'], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], ['anchovy'])
# ['anchovy']
# (['olive'], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], ['anchovy'])
# -----
# []
# ([], [])
# []
# ([], [])
# -----
# ['mushroom']
# (['mushroom'],)
# -----
# []
# ([],)
# -----
# ['mushroom']
# (['mushroom'],)
# -----
# ['ham', 'olive']
# (['ham', 'olive'],)
# -----
# ['pepperoni', 'anchovy', 'mushroom']
# (['pepperoni', 'anchovy', 'mushroom'],)
# -----
# -----
# []
# ([], ['ham'], ['pepperoni', 'olive'], ['mushroom'])
# ['ham']
# ([], ['ham'], ['pepperoni', 'olive'], ['mushroom'])
# ['pepperoni', 'olive']
# ([], ['ham'], ['pepperoni', 'olive'], ['mushroom'])
# ['mushroom']
# ([], ['ham'], ['pepperoni', 'olive'], ['mushroom'])
# -----
# -----
# ['mushroom', 'mushroom']
# (['mushroom', 'mushroom'], ['ham'], [])
# ['ham']
# (['mushroom', 'mushroom'], ['ham'], [])
# []
# (['mushroom', 'mushroom'], ['ham'], [])
# -----
# ['mushroom', 'mushroom']
# (['mushroom', 'mushroom'],)
# -----
# []
# ([], [], ['ham'])
# []
# ([], [], ['ham'])
# ['ham']
# ([], [], ['ham'])
# -----
# ['ham', 'olive', 'olive']
# (['ham', 'olive', 'olive'], ['ham', 'olive'])
# ['ham', 'olive']
# (['ham', 'olive', 'olive'], ['ham', 'olive'])
# -----
# -----
# -----
# ['pepperoni', 'anchovy', 'ham']
# (['pepperoni', 'anchovy', 'ham'],)
# -----
# []
# ([], ['anchovy', 'olive'])
# ['anchovy', 'olive']
# ([], ['anchovy', 'olive'])
# -----
# ['olive', 'olive']
# (['olive', 'olive'], ['mushroom', 'mushroom', 'ham'])
# ['mushroom', 'mushroom', 'ham']
# (['olive', 'olive'], ['mushroom', 'mushroom', 'ham'])
# -----
# ['anchovy', 'pepperoni', 'pepperoni']
# (['anchovy', 'pepperoni', 'pepperoni'], ['pepperoni', 'anchovy'])
# ['pepperoni', 'anchovy']
# (['anchovy', 'pepperoni', 'pepperoni'], ['pepperoni', 'anchovy'])
# -----
# ['anchovy']
# (['anchovy'],)
# -----
# ['mushroom', 'anchovy', 'pepperoni']
# (['mushroom', 'anchovy', 'pepperoni'], [], ['mushroom', 'olive'])
# []
# (['mushroom', 'anchovy', 'pepperoni'], [], ['mushroom', 'olive'])
# ['mushroom', 'olive']
# (['mushroom', 'anchovy', 'pepperoni'], [], ['mushroom', 'olive'])
# -----
# ['mushroom', 'mushroom', 'mushroom']
# (['mushroom', 'mushroom', 'mushroom'],)
# -----
# ['anchovy']
# (['anchovy'], ['olive', 'ham', 'pepperoni'], ['ham'])
# ['olive', 'ham', 'pepperoni']
# (['anchovy'], ['olive', 'ham', 'pepperoni'], ['ham'])
# ['ham']
# (['anchovy'], ['olive', 'ham', 'pepperoni'], ['ham'])
# -----
# ['anchovy', 'olive']
# (['anchovy', 'olive'], ['anchovy', 'ham'], ['anchovy'], ['ham', 'olive'])
# ['anchovy', 'ham']
# (['anchovy', 'olive'], ['anchovy', 'ham'], ['anchovy'], ['ham', 'olive'])
# ['anchovy']
# (['anchovy', 'olive'], ['anchovy', 'ham'], ['anchovy'], ['ham', 'olive'])
# ['ham', 'olive']
# (['anchovy', 'olive'], ['anchovy', 'ham'], ['anchovy'], ['ham', 'olive'])
# -----
# -----
# ['mushroom', 'ham', 'olive']
# (['mushroom', 'ham', 'olive'],)
# -----
# -----
# ['olive', 'olive', 'anchovy']
# (['olive', 'olive', 'anchovy'], [])
# []
# (['olive', 'olive', 'anchovy'], [])
# -----
# ['anchovy', 'anchovy']
# (['anchovy', 'anchovy'],)
# -----
# ['mushroom', 'mushroom', 'mushroom']
# (['mushroom', 'mushroom', 'mushroom'], [], [], [])
# []
# (['mushroom', 'mushroom', 'mushroom'], [], [], [])
# []
# (['mushroom', 'mushroom', 'mushroom'], [], [], [])
# []
# (['mushroom', 'mushroom', 'mushroom'], [], [], [])
# -----
# []
# ([], ['mushroom'], ['olive'], ['ham'])
# ['mushroom']
# ([], ['mushroom'], ['olive'], ['ham'])
# ['olive']
# ([], ['mushroom'], ['olive'], ['ham'])
# ['ham']
# ([], ['mushroom'], ['olive'], ['ham'])
# -----
# ['pepperoni', 'pepperoni']
# (['pepperoni', 'pepperoni'],)
# -----
# ['anchovy']
# (['anchovy'], ['olive', 'olive', 'pepperoni'], ['mushroom', 'mushroom'])
# ['olive', 'olive', 'pepperoni']
# (['anchovy'], ['olive', 'olive', 'pepperoni'], ['mushroom', 'mushroom'])
# ['mushroom', 'mushroom']
# (['anchovy'], ['olive', 'olive', 'pepperoni'], ['mushroom', 'mushroom'])
# -----
# ['anchovy']
# (['anchovy'], [])
# []
# (['anchovy'], [])
# -----
# ['ham']
# (['ham'], ['olive', 'ham', 'anchovy'])
# ['olive', 'ham', 'anchovy']
# (['ham'], ['olive', 'ham', 'anchovy'])
# -----
# ['ham', 'anchovy', 'ham']
# (['ham', 'anchovy', 'ham'], ['pepperoni', 'mushroom'], ['pepperoni', 'olive', 'pepperoni'])
# ['pepperoni', 'mushroom']
# (['ham', 'anchovy', 'ham'], ['pepperoni', 'mushroom'], ['pepperoni', 'olive', 'pepperoni'])
# ['pepperoni', 'olive', 'pepperoni']
# (['ham', 'anchovy', 'ham'], ['pepperoni', 'mushroom'], ['pepperoni', 'olive', 'pepperoni'])
# -----
# ['ham']
# (['ham'],)
# -----
# ['anchovy']
# (['anchovy'], ['olive'], ['olive'], ['olive', 'ham'])
# ['olive']
# (['anchovy'], ['olive'], ['olive'], ['olive', 'ham'])
# ['olive']
# (['anchovy'], ['olive'], ['olive'], ['olive', 'ham'])
# ['olive', 'ham']
# (['anchovy'], ['olive'], ['olive'], ['olive', 'ham'])
# -----
# ['pepperoni', 'pepperoni']
# (['pepperoni', 'pepperoni'], ['mushroom', 'olive', 'anchovy'])
# ['mushroom', 'olive', 'anchovy']
# (['pepperoni', 'pepperoni'], ['mushroom', 'olive', 'anchovy'])
# -----
# ['pepperoni']
# (['pepperoni'], [], ['ham', 'pepperoni', 'olive'], [])
# []
# (['pepperoni'], [], ['ham', 'pepperoni', 'olive'], [])
# ['ham', 'pepperoni', 'olive']
# (['pepperoni'], [], ['ham', 'pepperoni', 'olive'], [])
# []
# (['pepperoni'], [], ['ham', 'pepperoni', 'olive'], [])
# -----
# ['mushroom', 'pepperoni', 'anchovy']
# (['mushroom', 'pepperoni', 'anchovy'],)
# -----
# ['mushroom', 'mushroom']
# (['mushroom', 'mushroom'], ['pepperoni'])
# ['pepperoni']
# (['mushroom', 'mushroom'], ['pepperoni'])
# -----
# -----
# -----
# ['pepperoni', 'mushroom', 'mushroom']
# (['pepperoni', 'mushroom', 'mushroom'], [])
# []
# (['pepperoni', 'mushroom', 'mushroom'], [])
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'], [], [], ['ham', 'ham', 'mushroom'])
# []
# (['olive', 'mushroom'], [], [], ['ham', 'ham', 'mushroom'])
# []
# (['olive', 'mushroom'], [], [], ['ham', 'ham', 'mushroom'])
# ['ham', 'ham', 'mushroom']
# (['olive', 'mushroom'], [], [], ['ham', 'ham', 'mushroom'])
# -----
# -----
# []
# ([], ['olive', 'ham', 'ham'], ['olive', 'olive'])
# ['olive', 'ham', 'ham']
# ([], ['olive', 'ham', 'ham'], ['olive', 'olive'])
# ['olive', 'olive']
# ([], ['olive', 'ham', 'ham'], ['olive', 'olive'])
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'], ['pepperoni'], ['mushroom', 'pepperoni'], [])
# ['pepperoni']
# (['olive', 'mushroom'], ['pepperoni'], ['mushroom', 'pepperoni'], [])
# ['mushroom', 'pepperoni']
# (['olive', 'mushroom'], ['pepperoni'], ['mushroom', 'pepperoni'], [])
# []
# (['olive', 'mushroom'], ['pepperoni'], ['mushroom', 'pepperoni'], [])
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'],)
# -----
# -----
# []
# ([],)
# -----
# []
# ([],)
# -----
# []
# ([],)
# -----
# []
# ([], ['mushroom'], [])
# ['mushroom']
# ([], ['mushroom'], [])
# []
# ([], ['mushroom'], [])
# -----
# -----
# ['pepperoni']
# (['pepperoni'],)
# -----
# ['olive', 'olive']
# (['olive', 'olive'], ['ham', 'olive', 'ham'], ['ham', 'mushroom', 'anchovy'])
# ['ham', 'olive', 'ham']
# (['olive', 'olive'], ['ham', 'olive', 'ham'], ['ham', 'mushroom', 'anchovy'])
# ['ham', 'mushroom', 'anchovy']
# (['olive', 'olive'], ['ham', 'olive', 'ham'], ['ham', 'mushroom', 'anchovy'])
# -----
# -----
# -----
# []
# ([],)
# -----
# ['pepperoni']
# (['pepperoni'],)
# -----
# ['pepperoni']
# (['pepperoni'],)
# -----
# -----
# ['ham', 'olive', 'mushroom']
# (['ham', 'olive', 'mushroom'], [], ['olive'])
# []
# (['ham', 'olive', 'mushroom'], [], ['olive'])
# ['olive']
# (['ham', 'olive', 'mushroom'], [], ['olive'])
# -----
# ['pepperoni']
# (['pepperoni'], ['ham', 'ham', 'pepperoni'])
# ['ham', 'ham', 'pepperoni']
# (['pepperoni'], ['ham', 'ham', 'pepperoni'])
# -----
# -----
# -----
# -----
# []
# ([], [], ['anchovy'])
# []
# ([], [], ['anchovy'])
# ['anchovy']
# ([], [], ['anchovy'])
# -----
# -----
# []
# ([], ['anchovy'])
# ['anchovy']
# ([], ['anchovy'])
# -----
# ['olive']
# (['olive'], ['ham'])
# ['ham']
# (['olive'], ['ham'])
# -----
# ['pepperoni']
# (['pepperoni'], [], ['anchovy'], ['pepperoni'])
# []
# (['pepperoni'], [], ['anchovy'], ['pepperoni'])
# ['anchovy']
# (['pepperoni'], [], ['anchovy'], ['pepperoni'])
# ['pepperoni']
# (['pepperoni'], [], ['anchovy'], ['pepperoni'])
# -----
# ['olive', 'ham']
# (['olive', 'ham'], [], [])
# []
# (['olive', 'ham'], [], [])
# []
# (['olive', 'ham'], [], [])
# -----
# ['olive', 'anchovy', 'mushroom']
# (['olive', 'anchovy', 'mushroom'], ['ham', 'anchovy', 'pepperoni'])
# ['ham', 'anchovy', 'pepperoni']
# (['olive', 'anchovy', 'mushroom'], ['ham', 'anchovy', 'pepperoni'])
# -----
# ['pepperoni', 'ham']
# (['pepperoni', 'ham'],)
# -----
# ['pepperoni', 'mushroom', 'ham']
# (['pepperoni', 'mushroom', 'ham'], ['pepperoni', 'pepperoni', 'anchovy'])
# ['pepperoni', 'pepperoni', 'anchovy']
# (['pepperoni', 'mushroom', 'ham'], ['pepperoni', 'pepperoni', 'anchovy'])
# -----
# -----
# ['anchovy', 'pepperoni', 'pepperoni']
# (['anchovy', 'pepperoni', 'pepperoni'],)
# -----
# ['olive', 'ham', 'olive']
# (['olive', 'ham', 'olive'], ['mushroom'], ['anchovy', 'ham'])
# ['mushroom']
# (['olive', 'ham', 'olive'], ['mushroom'], ['anchovy', 'ham'])
# ['anchovy', 'ham']
# (['olive', 'ham', 'olive'], ['mushroom'], ['anchovy', 'ham'])
# -----
# []
# ([],)
# -----
# ['mushroom', 'ham']
# (['mushroom', 'ham'],)
# -----
# ['ham', 'mushroom']
# (['ham', 'mushroom'], [], ['olive'], ['anchovy'])
# []
# (['ham', 'mushroom'], [], ['olive'], ['anchovy'])
# ['olive']
# (['ham', 'mushroom'], [], ['olive'], ['anchovy'])
# ['anchovy']
# (['ham', 'mushroom'], [], ['olive'], ['anchovy'])
# -----
# -----
# ['mushroom', 'pepperoni']
# (['mushroom', 'pepperoni'], ['anchovy'])
# ['anchovy']
# (['mushroom', 'pepperoni'], ['anchovy'])
# -----
# []
# ([], ['olive'])
# ['olive']
# ([], ['olive'])
# -----
# ['anchovy', 'ham']
# (['anchovy', 'ham'], [])
# []
# (['anchovy', 'ham'], [])
# -----
# ['pepperoni', 'olive']
# (['pepperoni', 'olive'], ['pepperoni', 'ham'])
# ['pepperoni', 'ham']
# (['pepperoni', 'olive'], ['pepperoni', 'ham'])
# -----
# ['olive']
# (['olive'],)
# -----
# ['anchovy', 'anchovy', 'ham']
# (['anchovy', 'anchovy', 'ham'], ['olive', 'pepperoni', 'ham'], ['mushroom', 'mushroom'])
# ['olive', 'pepperoni', 'ham']
# (['anchovy', 'anchovy', 'ham'], ['olive', 'pepperoni', 'ham'], ['mushroom', 'mushroom'])
# ['mushroom', 'mushroom']
# (['anchovy', 'anchovy', 'ham'], ['olive', 'pepperoni', 'ham'], ['mushroom', 'mushroom'])
# -----
# ['pepperoni', 'mushroom']
# (['pepperoni', 'mushroom'], ['olive', 'olive', 'olive'], ['anchovy'], ['olive', 'olive'])
# ['olive', 'olive', 'olive']
# (['pepperoni', 'mushroom'], ['olive', 'olive', 'olive'], ['anchovy'], ['olive', 'olive'])
# ['anchovy']
# (['pepperoni', 'mushroom'], ['olive', 'olive', 'olive'], ['anchovy'], ['olive', 'olive'])
# ['olive', 'olive']
# (['pepperoni', 'mushroom'], ['olive', 'olive', 'olive'], ['anchovy'], ['olive', 'olive'])
# -----
# ['pepperoni', 'ham']
# (['pepperoni', 'ham'], ['mushroom', 'olive'])
# ['mushroom', 'olive']
# (['pepperoni', 'ham'], ['mushroom', 'olive'])
# -----
# ['pepperoni']
# (['pepperoni'], [])
# []
# (['pepperoni'], [])
# -----
# ['pepperoni', 'mushroom', 'mushroom']
# (['pepperoni', 'mushroom', 'mushroom'], [], ['mushroom', 'mushroom', 'anchovy'])
# []
# (['pepperoni', 'mushroom', 'mushroom'], [], ['mushroom', 'mushroom', 'anchovy'])
# ['mushroom', 'mushroom', 'anchovy']
# (['pepperoni', 'mushroom', 'mushroom'], [], ['mushroom', 'mushroom', 'anchovy'])
# -----
# -----
# ['anchovy', 'olive', 'mushroom']
# (['anchovy', 'olive', 'mushroom'],)
# -----
# -----
# -----
# ['mushroom']
# (['mushroom'], [], [], ['pepperoni'])
# []
# (['mushroom'], [], [], ['pepperoni'])
# []
# (['mushroom'], [], [], ['pepperoni'])
# ['pepperoni']
# (['mushroom'], [], [], ['pepperoni'])
# -----
# ['pepperoni', 'anchovy', 'pepperoni']
# (['pepperoni', 'anchovy', 'pepperoni'],)
# -----
# ['pepperoni', 'pepperoni', 'olive']
# (['pepperoni', 'pepperoni', 'olive'],)
# -----
# []
# ([], ['pepperoni', 'anchovy', 'ham'], ['anchovy'])
# ['pepperoni', 'anchovy', 'ham']
# ([], ['pepperoni', 'anchovy', 'ham'], ['anchovy'])
# ['anchovy']
# ([], ['pepperoni', 'anchovy', 'ham'], ['anchovy'])
# -----
# []
# ([], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], [])
# ['olive', 'ham', 'mushroom']
# ([], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], [])
# ['ham', 'mushroom']
# ([], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], [])
# []
# ([], ['olive', 'ham', 'mushroom'], ['ham', 'mushroom'], [])
# -----
# ['anchovy', 'anchovy', 'olive']
# (['anchovy', 'anchovy', 'olive'], ['ham', 'pepperoni'], ['olive'])
# ['ham', 'pepperoni']
# (['anchovy', 'anchovy', 'olive'], ['ham', 'pepperoni'], ['olive'])
# ['olive']
# (['anchovy', 'anchovy', 'olive'], ['ham', 'pepperoni'], ['olive'])
# -----
# -----
# ['olive']
# (['olive'], ['mushroom', 'olive', 'pepperoni'])
# ['mushroom', 'olive', 'pepperoni']
# (['olive'], ['mushroom', 'olive', 'pepperoni'])
# -----
# ['anchovy', 'pepperoni']
# (['anchovy', 'pepperoni'], [], ['mushroom', 'pepperoni', 'ham'])
# []
# (['anchovy', 'pepperoni'], [], ['mushroom', 'pepperoni', 'ham'])
# ['mushroom', 'pepperoni', 'ham']
# (['anchovy', 'pepperoni'], [], ['mushroom', 'pepperoni', 'ham'])
# -----
# ['pepperoni', 'mushroom', 'mushroom']
# (['pepperoni', 'mushroom', 'mushroom'], ['mushroom', 'anchovy'], ['pepperoni', 'olive'], ['mushroom', 'pepperoni'])
# ['mushroom', 'anchovy']
# (['pepperoni', 'mushroom', 'mushroom'], ['mushroom', 'anchovy'], ['pepperoni', 'olive'], ['mushroom', 'pepperoni'])
# ['pepperoni', 'olive']
# (['pepperoni', 'mushroom', 'mushroom'], ['mushroom', 'anchovy'], ['pepperoni', 'olive'], ['mushroom', 'pepperoni'])
# ['mushroom', 'pepperoni']
# (['pepperoni', 'mushroom', 'mushroom'], ['mushroom', 'anchovy'], ['pepperoni', 'olive'], ['mushroom', 'pepperoni'])
# -----
# []
# ([],)
# -----
# ['olive', 'anchovy']
# (['olive', 'anchovy'], ['anchovy'], [], ['anchovy', 'olive'])
# ['anchovy']
# (['olive', 'anchovy'], ['anchovy'], [], ['anchovy', 'olive'])
# []
# (['olive', 'anchovy'], ['anchovy'], [], ['anchovy', 'olive'])
# ['anchovy', 'olive']
# (['olive', 'anchovy'], ['anchovy'], [], ['anchovy', 'olive'])
# -----
# ['ham']
# (['ham'], ['ham', 'anchovy', 'anchovy'], ['olive', 'pepperoni', 'ham'], ['pepperoni', 'pepperoni'])
# ['ham', 'anchovy', 'anchovy']
# (['ham'], ['ham', 'anchovy', 'anchovy'], ['olive', 'pepperoni', 'ham'], ['pepperoni', 'pepperoni'])
# ['olive', 'pepperoni', 'ham']
# (['ham'], ['ham', 'anchovy', 'anchovy'], ['olive', 'pepperoni', 'ham'], ['pepperoni', 'pepperoni'])
# ['pepperoni', 'pepperoni']
# (['ham'], ['ham', 'anchovy', 'anchovy'], ['olive', 'pepperoni', 'ham'], ['pepperoni', 'pepperoni'])
# -----
# ['olive', 'anchovy', 'anchovy']
# (['olive', 'anchovy', 'anchovy'], ['olive', 'anchovy', 'mushroom'], ['mushroom', 'olive'], ['ham', 'ham', 'mushroom'])
# ['olive', 'anchovy', 'mushroom']
# (['olive', 'anchovy', 'anchovy'], ['olive', 'anchovy', 'mushroom'], ['mushroom', 'olive'], ['ham', 'ham', 'mushroom'])
# ['mushroom', 'olive']
# (['olive', 'anchovy', 'anchovy'], ['olive', 'anchovy', 'mushroom'], ['mushroom', 'olive'], ['ham', 'ham', 'mushroom'])
# ['ham', 'ham', 'mushroom']
# (['olive', 'anchovy', 'anchovy'], ['olive', 'anchovy', 'mushroom'], ['mushroom', 'olive'], ['ham', 'ham', 'mushroom'])
# -----
# ['pepperoni', 'olive']
# (['pepperoni', 'olive'], ['ham'], ['mushroom', 'pepperoni'], ['anchovy', 'pepperoni', 'mushroom'])
# ['ham']
# (['pepperoni', 'olive'], ['ham'], ['mushroom', 'pepperoni'], ['anchovy', 'pepperoni', 'mushroom'])
# ['mushroom', 'pepperoni']
# (['pepperoni', 'olive'], ['ham'], ['mushroom', 'pepperoni'], ['anchovy', 'pepperoni', 'mushroom'])
# ['anchovy', 'pepperoni', 'mushroom']
# (['pepperoni', 'olive'], ['ham'], ['mushroom', 'pepperoni'], ['anchovy', 'pepperoni', 'mushroom'])
# -----
# []
# ([], ['pepperoni'], [], ['olive', 'olive', 'ham'])
# ['pepperoni']
# ([], ['pepperoni'], [], ['olive', 'olive', 'ham'])
# []
# ([], ['pepperoni'], [], ['olive', 'olive', 'ham'])
# ['olive', 'olive', 'ham']
# ([], ['pepperoni'], [], ['olive', 'olive', 'ham'])
# -----
# -----
# ['ham', 'olive', 'anchovy']
# (['ham', 'olive', 'anchovy'], ['ham', 'mushroom'], ['olive', 'mushroom', 'anchovy'], ['ham'])
# ['ham', 'mushroom']
# (['ham', 'olive', 'anchovy'], ['ham', 'mushroom'], ['olive', 'mushroom', 'anchovy'], ['ham'])
# ['olive', 'mushroom', 'anchovy']
# (['ham', 'olive', 'anchovy'], ['ham', 'mushroom'], ['olive', 'mushroom', 'anchovy'], ['ham'])
# ['ham']
# (['ham', 'olive', 'anchovy'], ['ham', 'mushroom'], ['olive', 'mushroom', 'anchovy'], ['ham'])
# -----
# ['mushroom', 'anchovy']
# (['mushroom', 'anchovy'], ['pepperoni', 'anchovy', 'mushroom'])
# ['pepperoni', 'anchovy', 'mushroom']
# (['mushroom', 'anchovy'], ['pepperoni', 'anchovy', 'mushroom'])
# -----
# ['pepperoni']
# (['pepperoni'], ['anchovy', 'pepperoni', 'olive'], [])
# ['anchovy', 'pepperoni', 'olive']
# (['pepperoni'], ['anchovy', 'pepperoni', 'olive'], [])
# []
# (['pepperoni'], ['anchovy', 'pepperoni', 'olive'], [])
# -----
# ['mushroom']
# (['mushroom'],)
# -----
# -----
# -----
# ['ham', 'ham', 'olive']
# (['ham', 'ham', 'olive'], [])
# []
# (['ham', 'ham', 'olive'], [])
# -----
# ['pepperoni', 'anchovy']
# (['pepperoni', 'anchovy'], [])
# []
# (['pepperoni', 'anchovy'], [])
# -----
# ['ham', 'anchovy']
# (['ham', 'anchovy'], [], ['mushroom', 'pepperoni', 'pepperoni'], ['anchovy', 'anchovy', 'ham'])
# []
# (['ham', 'anchovy'], [], ['mushroom', 'pepperoni', 'pepperoni'], ['anchovy', 'anchovy', 'ham'])
# ['mushroom', 'pepperoni', 'pepperoni']
# (['ham', 'anchovy'], [], ['mushroom', 'pepperoni', 'pepperoni'], ['anchovy', 'anchovy', 'ham'])
# ['anchovy', 'anchovy', 'ham']
# (['ham', 'anchovy'], [], ['mushroom', 'pepperoni', 'pepperoni'], ['anchovy', 'anchovy', 'ham'])
# -----
# -----
# ['ham']
# (['ham'], ['olive', 'olive', 'olive'], ['mushroom', 'ham', 'anchovy'], [])
# ['olive', 'olive', 'olive']
# (['ham'], ['olive', 'olive', 'olive'], ['mushroom', 'ham', 'anchovy'], [])
# ['mushroom', 'ham', 'anchovy']
# (['ham'], ['olive', 'olive', 'olive'], ['mushroom', 'ham', 'anchovy'], [])
# []
# (['ham'], ['olive', 'olive', 'olive'], ['mushroom', 'ham', 'anchovy'], [])
# -----
# -----
# ['mushroom']
# (['mushroom'], ['anchovy', 'anchovy', 'anchovy'])
# ['anchovy', 'anchovy', 'anchovy']
# (['mushroom'], ['anchovy', 'anchovy', 'anchovy'])
# -----
# []
# ([], ['mushroom'], ['olive', 'ham'])
# ['mushroom']
# ([], ['mushroom'], ['olive', 'ham'])
# ['olive', 'ham']
# ([], ['mushroom'], ['olive', 'ham'])
# -----
# ['olive', 'pepperoni', 'anchovy']
# (['olive', 'pepperoni', 'anchovy'],)
# -----
# ['anchovy', 'anchovy']
# (['anchovy', 'anchovy'], ['pepperoni'], ['mushroom'], ['mushroom', 'anchovy', 'anchovy'])
# ['pepperoni']
# (['anchovy', 'anchovy'], ['pepperoni'], ['mushroom'], ['mushroom', 'anchovy', 'anchovy'])
# ['mushroom']
# (['anchovy', 'anchovy'], ['pepperoni'], ['mushroom'], ['mushroom', 'anchovy', 'anchovy'])
# ['mushroom', 'anchovy', 'anchovy']
# (['anchovy', 'anchovy'], ['pepperoni'], ['mushroom'], ['mushroom', 'anchovy', 'anchovy'])
# -----
# ['pepperoni', 'pepperoni', 'ham']
# (['pepperoni', 'pepperoni', 'ham'], ['anchovy', 'ham'], ['olive'])
# ['anchovy', 'ham']
# (['pepperoni', 'pepperoni', 'ham'], ['anchovy', 'ham'], ['olive'])
# ['olive']
# (['pepperoni', 'pepperoni', 'ham'], ['anchovy', 'ham'], ['olive'])
# -----
# -----
# ['pepperoni', 'ham']
# (['pepperoni', 'ham'], ['pepperoni'])
# ['pepperoni']
# (['pepperoni', 'ham'], ['pepperoni'])
# -----
# ['pepperoni', 'anchovy']
# (['pepperoni', 'anchovy'], ['olive', 'ham', 'olive'])
# ['olive', 'ham', 'olive']
# (['pepperoni', 'anchovy'], ['olive', 'ham', 'olive'])
# -----
# -----
# ['mushroom']
# (['mushroom'], ['olive', 'anchovy', 'pepperoni'], ['mushroom'], ['olive', 'olive', 'ham'])
# ['olive', 'anchovy', 'pepperoni']
# (['mushroom'], ['olive', 'anchovy', 'pepperoni'], ['mushroom'], ['olive', 'olive', 'ham'])
# ['mushroom']
# (['mushroom'], ['olive', 'anchovy', 'pepperoni'], ['mushroom'], ['olive', 'olive', 'ham'])
# ['olive', 'olive', 'ham']
# (['mushroom'], ['olive', 'anchovy', 'pepperoni'], ['mushroom'], ['olive', 'olive', 'ham'])
# -----
# []
# ([],)
# -----
# ['ham', 'anchovy', 'mushroom']
# (['ham', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'], ['anchovy', 'anchovy'])
# []
# (['ham', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'], ['anchovy', 'anchovy'])
# ['mushroom', 'ham']
# (['ham', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'], ['anchovy', 'anchovy'])
# ['anchovy', 'anchovy']
# (['ham', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'], ['anchovy', 'anchovy'])
# -----
# ['pepperoni']
# (['pepperoni'],)
# -----
# ['ham']
# (['ham'], ['ham', 'ham'], ['pepperoni', 'anchovy'], ['anchovy'])
# ['ham', 'ham']
# (['ham'], ['ham', 'ham'], ['pepperoni', 'anchovy'], ['anchovy'])
# ['pepperoni', 'anchovy']
# (['ham'], ['ham', 'ham'], ['pepperoni', 'anchovy'], ['anchovy'])
# ['anchovy']
# (['ham'], ['ham', 'ham'], ['pepperoni', 'anchovy'], ['anchovy'])
# -----
# ['ham', 'ham']
# (['ham', 'ham'], [], ['pepperoni', 'mushroom'], ['mushroom', 'ham'])
# []
# (['ham', 'ham'], [], ['pepperoni', 'mushroom'], ['mushroom', 'ham'])
# ['pepperoni', 'mushroom']
# (['ham', 'ham'], [], ['pepperoni', 'mushroom'], ['mushroom', 'ham'])
# ['mushroom', 'ham']
# (['ham', 'ham'], [], ['pepperoni', 'mushroom'], ['mushroom', 'ham'])
# -----
# []
# ([], ['pepperoni', 'ham', 'pepperoni'])
# ['pepperoni', 'ham', 'pepperoni']
# ([], ['pepperoni', 'ham', 'pepperoni'])
# -----
# []
# ([], [], ['ham'], ['ham', 'pepperoni'])
# []
# ([], [], ['ham'], ['ham', 'pepperoni'])
# ['ham']
# ([], [], ['ham'], ['ham', 'pepperoni'])
# ['ham', 'pepperoni']
# ([], [], ['ham'], ['ham', 'pepperoni'])
# -----
# ['mushroom', 'ham', 'pepperoni']
# (['mushroom', 'ham', 'pepperoni'], [], ['anchovy'])
# []
# (['mushroom', 'ham', 'pepperoni'], [], ['anchovy'])
# ['anchovy']
# (['mushroom', 'ham', 'pepperoni'], [], ['anchovy'])
# -----
# ['mushroom']
# (['mushroom'], ['mushroom', 'anchovy', 'pepperoni'], [], [])
# ['mushroom', 'anchovy', 'pepperoni']
# (['mushroom'], ['mushroom', 'anchovy', 'pepperoni'], [], [])
# []
# (['mushroom'], ['mushroom', 'anchovy', 'pepperoni'], [], [])
# []
# (['mushroom'], ['mushroom', 'anchovy', 'pepperoni'], [], [])
# -----
# ['ham', 'mushroom']
# (['ham', 'mushroom'], ['mushroom', 'mushroom', 'anchovy'])
# ['mushroom', 'mushroom', 'anchovy']
# (['ham', 'mushroom'], ['mushroom', 'mushroom', 'anchovy'])
# -----
# ['anchovy', 'anchovy']
# (['anchovy', 'anchovy'], ['pepperoni'])
# ['pepperoni']
# (['anchovy', 'anchovy'], ['pepperoni'])
# -----
# -----
# ['ham']
# (['ham'], ['ham', 'mushroom', 'olive'], ['pepperoni', 'pepperoni', 'anchovy'], ['ham', 'mushroom', 'olive'])
# ['ham', 'mushroom', 'olive']
# (['ham'], ['ham', 'mushroom', 'olive'], ['pepperoni', 'pepperoni', 'anchovy'], ['ham', 'mushroom', 'olive'])
# ['pepperoni', 'pepperoni', 'anchovy']
# (['ham'], ['ham', 'mushroom', 'olive'], ['pepperoni', 'pepperoni', 'anchovy'], ['ham', 'mushroom', 'olive'])
# ['ham', 'mushroom', 'olive']
# (['ham'], ['ham', 'mushroom', 'olive'], ['pepperoni', 'pepperoni', 'anchovy'], ['ham', 'mushroom', 'olive'])
# -----
# -----
# -----
# ['pepperoni']
# (['pepperoni'], [])
# []
# (['pepperoni'], [])
# -----
# -----
# ['olive', 'anchovy']
# (['olive', 'anchovy'], ['ham', 'anchovy', 'pepperoni'])
# ['ham', 'anchovy', 'pepperoni']
# (['olive', 'anchovy'], ['ham', 'anchovy', 'pepperoni'])
# -----
# ['mushroom', 'anchovy']
# (['mushroom', 'anchovy'],)
# -----
# -----
# ['pepperoni', 'ham']
# (['pepperoni', 'ham'], [])
# []
# (['pepperoni', 'ham'], [])
# -----
# ['anchovy', 'ham', 'olive']
# (['anchovy', 'ham', 'olive'],)
# -----
# []
# ([], ['mushroom', 'anchovy'], ['mushroom'])
# ['mushroom', 'anchovy']
# ([], ['mushroom', 'anchovy'], ['mushroom'])
# ['mushroom']
# ([], ['mushroom', 'anchovy'], ['mushroom'])
# -----
# -----
# ['ham', 'pepperoni', 'olive']
# (['ham', 'pepperoni', 'olive'], ['anchovy'])
# ['anchovy']
# (['ham', 'pepperoni', 'olive'], ['anchovy'])
# -----
# ['pepperoni', 'pepperoni', 'olive']
# (['pepperoni', 'pepperoni', 'olive'], ['mushroom', 'pepperoni', 'anchovy'], ['ham', 'ham', 'ham'], ['anchovy', 'pepperoni', 'pepperoni'])
# ['mushroom', 'pepperoni', 'anchovy']
# (['pepperoni', 'pepperoni', 'olive'], ['mushroom', 'pepperoni', 'anchovy'], ['ham', 'ham', 'ham'], ['anchovy', 'pepperoni', 'pepperoni'])
# ['ham', 'ham', 'ham']
# (['pepperoni', 'pepperoni', 'olive'], ['mushroom', 'pepperoni', 'anchovy'], ['ham', 'ham', 'ham'], ['anchovy', 'pepperoni', 'pepperoni'])
# ['anchovy', 'pepperoni', 'pepperoni']
# (['pepperoni', 'pepperoni', 'olive'], ['mushroom', 'pepperoni', 'anchovy'], ['ham', 'ham', 'ham'], ['anchovy', 'pepperoni', 'pepperoni'])
# -----
# []
# ([], ['anchovy'])
# ['anchovy']
# ([], ['anchovy'])
# -----
# ['pepperoni', 'olive']
# (['pepperoni', 'olive'],)
# -----
# ['ham', 'anchovy', 'mushroom']
# (['ham', 'anchovy', 'mushroom'], ['olive', 'olive'], ['ham', 'mushroom', 'mushroom'], ['ham', 'mushroom', 'pepperoni'])
# ['olive', 'olive']
# (['ham', 'anchovy', 'mushroom'], ['olive', 'olive'], ['ham', 'mushroom', 'mushroom'], ['ham', 'mushroom', 'pepperoni'])
# ['ham', 'mushroom', 'mushroom']
# (['ham', 'anchovy', 'mushroom'], ['olive', 'olive'], ['ham', 'mushroom', 'mushroom'], ['ham', 'mushroom', 'pepperoni'])
# ['ham', 'mushroom', 'pepperoni']
# (['ham', 'anchovy', 'mushroom'], ['olive', 'olive'], ['ham', 'mushroom', 'mushroom'], ['ham', 'mushroom', 'pepperoni'])
# -----
# []
# ([], [], ['pepperoni'], ['mushroom', 'mushroom', 'olive'])
# []
# ([], [], ['pepperoni'], ['mushroom', 'mushroom', 'olive'])
# ['pepperoni']
# ([], [], ['pepperoni'], ['mushroom', 'mushroom', 'olive'])
# ['mushroom', 'mushroom', 'olive']
# ([], [], ['pepperoni'], ['mushroom', 'mushroom', 'olive'])
# -----
# ['ham', 'pepperoni', 'mushroom']
# (['ham', 'pepperoni', 'mushroom'], ['olive'], ['pepperoni', 'pepperoni', 'olive'], ['pepperoni', 'ham', 'mushroom'])
# ['olive']
# (['ham', 'pepperoni', 'mushroom'], ['olive'], ['pepperoni', 'pepperoni', 'olive'], ['pepperoni', 'ham', 'mushroom'])
# ['pepperoni', 'pepperoni', 'olive']
# (['ham', 'pepperoni', 'mushroom'], ['olive'], ['pepperoni', 'pepperoni', 'olive'], ['pepperoni', 'ham', 'mushroom'])
# ['pepperoni', 'ham', 'mushroom']
# (['ham', 'pepperoni', 'mushroom'], ['olive'], ['pepperoni', 'pepperoni', 'olive'], ['pepperoni', 'ham', 'mushroom'])
# -----
# -----
# ['anchovy', 'anchovy', 'anchovy']
# (['anchovy', 'anchovy', 'anchovy'], ['pepperoni', 'ham', 'ham'], ['pepperoni', 'anchovy'])
# ['pepperoni', 'ham', 'ham']
# (['anchovy', 'anchovy', 'anchovy'], ['pepperoni', 'ham', 'ham'], ['pepperoni', 'anchovy'])
# ['pepperoni', 'anchovy']
# (['anchovy', 'anchovy', 'anchovy'], ['pepperoni', 'ham', 'ham'], ['pepperoni', 'anchovy'])
# -----
# ['pepperoni']
# (['pepperoni'],)
# -----
# ['mushroom']
# (['mushroom'],)
# -----
# []
# ([], ['anchovy', 'pepperoni', 'anchovy'], [])
# ['anchovy', 'pepperoni', 'anchovy']
# ([], ['anchovy', 'pepperoni', 'anchovy'], [])
# []
# ([], ['anchovy', 'pepperoni', 'anchovy'], [])
# -----
# ['anchovy', 'olive']
# (['anchovy', 'olive'], ['anchovy', 'anchovy', 'anchovy'], ['ham', 'ham', 'ham'], ['mushroom'])
# ['anchovy', 'anchovy', 'anchovy']
# (['anchovy', 'olive'], ['anchovy', 'anchovy', 'anchovy'], ['ham', 'ham', 'ham'], ['mushroom'])
# ['ham', 'ham', 'ham']
# (['anchovy', 'olive'], ['anchovy', 'anchovy', 'anchovy'], ['ham', 'ham', 'ham'], ['mushroom'])
# ['mushroom']
# (['anchovy', 'olive'], ['anchovy', 'anchovy', 'anchovy'], ['ham', 'ham', 'ham'], ['mushroom'])
# -----
# -----
# []
# ([], ['ham', 'ham', 'mushroom'])
# ['ham', 'ham', 'mushroom']
# ([], ['ham', 'ham', 'mushroom'])
# -----
# ['pepperoni', 'mushroom', 'mushroom']
# (['pepperoni', 'mushroom', 'mushroom'], ['ham', 'pepperoni'], ['pepperoni'], ['anchovy'])
# ['ham', 'pepperoni']
# (['pepperoni', 'mushroom', 'mushroom'], ['ham', 'pepperoni'], ['pepperoni'], ['anchovy'])
# ['pepperoni']
# (['pepperoni', 'mushroom', 'mushroom'], ['ham', 'pepperoni'], ['pepperoni'], ['anchovy'])
# ['anchovy']
# (['pepperoni', 'mushroom', 'mushroom'], ['ham', 'pepperoni'], ['pepperoni'], ['anchovy'])
# -----
# ['ham', 'anchovy']
# (['ham', 'anchovy'], ['olive', 'pepperoni', 'olive'], ['mushroom', 'anchovy'], ['olive', 'olive', 'mushroom'])
# ['olive', 'pepperoni', 'olive']
# (['ham', 'anchovy'], ['olive', 'pepperoni', 'olive'], ['mushroom', 'anchovy'], ['olive', 'olive', 'mushroom'])
# ['mushroom', 'anchovy']
# (['ham', 'anchovy'], ['olive', 'pepperoni', 'olive'], ['mushroom', 'anchovy'], ['olive', 'olive', 'mushroom'])
# ['olive', 'olive', 'mushroom']
# (['ham', 'anchovy'], ['olive', 'pepperoni', 'olive'], ['mushroom', 'anchovy'], ['olive', 'olive', 'mushroom'])
# -----
# []
# ([],)
# -----
# ['mushroom', 'mushroom']
# (['mushroom', 'mushroom'], [], [])
# []
# (['mushroom', 'mushroom'], [], [])
# []
# (['mushroom', 'mushroom'], [], [])
# -----
# ['mushroom']
# (['mushroom'],)
# -----
# ['mushroom']
# (['mushroom'], ['anchovy', 'olive', 'mushroom'], ['mushroom', 'pepperoni', 'anchovy'])
# ['anchovy', 'olive', 'mushroom']
# (['mushroom'], ['anchovy', 'olive', 'mushroom'], ['mushroom', 'pepperoni', 'anchovy'])
# ['mushroom', 'pepperoni', 'anchovy']
# (['mushroom'], ['anchovy', 'olive', 'mushroom'], ['mushroom', 'pepperoni', 'anchovy'])
# -----
# ['pepperoni', 'ham']
# (['pepperoni', 'ham'],)
# -----
# ['pepperoni', 'olive', 'ham']
# (['pepperoni', 'olive', 'ham'], ['ham'], ['anchovy'], [])
# ['ham']
# (['pepperoni', 'olive', 'ham'], ['ham'], ['anchovy'], [])
# ['anchovy']
# (['pepperoni', 'olive', 'ham'], ['ham'], ['anchovy'], [])
# []
# (['pepperoni', 'olive', 'ham'], ['ham'], ['anchovy'], [])
# -----
# -----
# ['olive', 'pepperoni', 'anchovy']
# (['olive', 'pepperoni', 'anchovy'], [], ['mushroom', 'olive'])
# []
# (['olive', 'pepperoni', 'anchovy'], [], ['mushroom', 'olive'])
# ['mushroom', 'olive']
# (['olive', 'pepperoni', 'anchovy'], [], ['mushroom', 'olive'])
# -----
# ['anchovy', 'pepperoni', 'ham']
# (['anchovy', 'pepperoni', 'ham'], ['anchovy', 'anchovy'], [], ['ham', 'ham'])
# ['anchovy', 'anchovy']
# (['anchovy', 'pepperoni', 'ham'], ['anchovy', 'anchovy'], [], ['ham', 'ham'])
# []
# (['anchovy', 'pepperoni', 'ham'], ['anchovy', 'anchovy'], [], ['ham', 'ham'])
# ['ham', 'ham']
# (['anchovy', 'pepperoni', 'ham'], ['anchovy', 'anchovy'], [], ['ham', 'ham'])
# -----
# []
# ([],)
# -----
# ['olive']
# (['olive'], ['mushroom', 'ham'], ['mushroom', 'olive'])
# ['mushroom', 'ham']
# (['olive'], ['mushroom', 'ham'], ['mushroom', 'olive'])
# ['mushroom', 'olive']
# (['olive'], ['mushroom', 'ham'], ['mushroom', 'olive'])
# -----
# -----
# []
# ([], ['pepperoni', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['pepperoni', 'mushroom'])
# ['pepperoni', 'mushroom']
# ([], ['pepperoni', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['pepperoni', 'mushroom'])
# ['mushroom', 'olive', 'anchovy']
# ([], ['pepperoni', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['pepperoni', 'mushroom'])
# ['pepperoni', 'mushroom']
# ([], ['pepperoni', 'mushroom'], ['mushroom', 'olive', 'anchovy'], ['pepperoni', 'mushroom'])
# -----
# ['pepperoni', 'pepperoni', 'ham']
# (['pepperoni', 'pepperoni', 'ham'], [])
# []
# (['pepperoni', 'pepperoni', 'ham'], [])
# -----
# []
# ([], ['mushroom'])
# ['mushroom']
# ([], ['mushroom'])
# -----
# []
# ([], ['pepperoni', 'pepperoni'], ['ham', 'ham'], [])
# ['pepperoni', 'pepperoni']
# ([], ['pepperoni', 'pepperoni'], ['ham', 'ham'], [])
# ['ham', 'ham']
# ([], ['pepperoni', 'pepperoni'], ['ham', 'ham'], [])
# []
# ([], ['pepperoni', 'pepperoni'], ['ham', 'ham'], [])
# -----
# []
# ([], ['mushroom', 'mushroom', 'mushroom'])
# ['mushroom', 'mushroom', 'mushroom']
# ([], ['mushroom', 'mushroom', 'mushroom'])
# -----
# ['anchovy']
# (['anchovy'], [], ['mushroom', 'ham'])
# []
# (['anchovy'], [], ['mushroom', 'ham'])
# ['mushroom', 'ham']
# (['anchovy'], [], ['mushroom', 'ham'])
# -----
# -----
# ['anchovy', 'olive']
# (['anchovy', 'olive'],)
# -----
# ['olive', 'olive', 'mushroom']
# (['olive', 'olive', 'mushroom'], ['olive', 'pepperoni', 'mushroom'], [])
# ['olive', 'pepperoni', 'mushroom']
# (['olive', 'olive', 'mushroom'], ['olive', 'pepperoni', 'mushroom'], [])
# []
# (['olive', 'olive', 'mushroom'], ['olive', 'pepperoni', 'mushroom'], [])
# -----
# -----
# -----
# ['ham', 'ham']
# (['ham', 'ham'],)
# -----
# ['anchovy']
# (['anchovy'], ['pepperoni'], ['pepperoni', 'pepperoni'], ['pepperoni', 'anchovy'])
# ['pepperoni']
# (['anchovy'], ['pepperoni'], ['pepperoni', 'pepperoni'], ['pepperoni', 'anchovy'])
# ['pepperoni', 'pepperoni']
# (['anchovy'], ['pepperoni'], ['pepperoni', 'pepperoni'], ['pepperoni', 'anchovy'])
# ['pepperoni', 'anchovy']
# (['anchovy'], ['pepperoni'], ['pepperoni', 'pepperoni'], ['pepperoni', 'anchovy'])
# -----
# ['olive']
# (['olive'],)
# -----
# ['anchovy']
# (['anchovy'], ['pepperoni', 'anchovy', 'ham'], ['pepperoni'])
# ['pepperoni', 'anchovy', 'ham']
# (['anchovy'], ['pepperoni', 'anchovy', 'ham'], ['pepperoni'])
# ['pepperoni']
# (['anchovy'], ['pepperoni', 'anchovy', 'ham'], ['pepperoni'])
# -----
# ['olive', 'mushroom', 'ham']
# (['olive', 'mushroom', 'ham'], ['ham', 'pepperoni'], ['olive', 'mushroom', 'pepperoni'])
# ['ham', 'pepperoni']
# (['olive', 'mushroom', 'ham'], ['ham', 'pepperoni'], ['olive', 'mushroom', 'pepperoni'])
# ['olive', 'mushroom', 'pepperoni']
# (['olive', 'mushroom', 'ham'], ['ham', 'pepperoni'], ['olive', 'mushroom', 'pepperoni'])
# -----
# ['mushroom', 'pepperoni']
# (['mushroom', 'pepperoni'],)
# -----
# ['anchovy', 'anchovy', 'pepperoni']
# (['anchovy', 'anchovy', 'pepperoni'],)
# -----
# ['ham']
# (['ham'], [])
# []
# (['ham'], [])
# -----
# ['ham', 'olive', 'anchovy']
# (['ham', 'olive', 'anchovy'], [], ['mushroom', 'mushroom'])
# []
# (['ham', 'olive', 'anchovy'], [], ['mushroom', 'mushroom'])
# ['mushroom', 'mushroom']
# (['ham', 'olive', 'anchovy'], [], ['mushroom', 'mushroom'])
# -----
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'], ['pepperoni', 'anchovy', 'olive'], [])
# ['pepperoni', 'anchovy', 'olive']
# (['olive', 'mushroom'], ['pepperoni', 'anchovy', 'olive'], [])
# []
# (['olive', 'mushroom'], ['pepperoni', 'anchovy', 'olive'], [])
# -----
# []
# ([], [])
# []
# ([], [])
# -----
# ['mushroom', 'anchovy', 'olive']
# (['mushroom', 'anchovy', 'olive'],)
# -----
# -----
# ['anchovy', 'ham', 'ham']
# (['anchovy', 'ham', 'ham'],)
# -----
# -----
# ['pepperoni', 'ham', 'pepperoni']
# (['pepperoni', 'ham', 'pepperoni'],)
# -----
# -----
# ['pepperoni', 'mushroom']
# (['pepperoni', 'mushroom'], ['pepperoni'])
# ['pepperoni']
# (['pepperoni', 'mushroom'], ['pepperoni'])
# -----
# ['anchovy', 'pepperoni']
# (['anchovy', 'pepperoni'], ['olive'], ['anchovy', 'ham', 'anchovy'])
# ['olive']
# (['anchovy', 'pepperoni'], ['olive'], ['anchovy', 'ham', 'anchovy'])
# ['anchovy', 'ham', 'anchovy']
# (['anchovy', 'pepperoni'], ['olive'], ['anchovy', 'ham', 'anchovy'])
# -----
# -----
# ['pepperoni']
# (['pepperoni'], ['olive', 'olive'], ['anchovy', 'anchovy'], ['olive', 'pepperoni', 'pepperoni'])
# ['olive', 'olive']
# (['pepperoni'], ['olive', 'olive'], ['anchovy', 'anchovy'], ['olive', 'pepperoni', 'pepperoni'])
# ['anchovy', 'anchovy']
# (['pepperoni'], ['olive', 'olive'], ['anchovy', 'anchovy'], ['olive', 'pepperoni', 'pepperoni'])
# ['olive', 'pepperoni', 'pepperoni']
# (['pepperoni'], ['olive', 'olive'], ['anchovy', 'anchovy'], ['olive', 'pepperoni', 'pepperoni'])
# -----
# -----
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'], ['olive'])
# ['olive']
# (['olive', 'mushroom'], ['olive'])
# -----
# ['anchovy', 'anchovy', 'mushroom']
# (['anchovy', 'anchovy', 'mushroom'], ['pepperoni'])
# ['pepperoni']
# (['anchovy', 'anchovy', 'mushroom'], ['pepperoni'])
# -----
# ['ham']
# (['ham'], ['ham', 'anchovy'], ['mushroom'])
# ['ham', 'anchovy']
# (['ham'], ['ham', 'anchovy'], ['mushroom'])
# ['mushroom']
# (['ham'], ['ham', 'anchovy'], ['mushroom'])
# -----
# ['pepperoni']
# (['pepperoni'],)
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'], ['ham'], [], [])
# ['ham']
# (['olive', 'mushroom'], ['ham'], [], [])
# []
# (['olive', 'mushroom'], ['ham'], [], [])
# []
# (['olive', 'mushroom'], ['ham'], [], [])
# -----
# ['pepperoni', 'anchovy', 'ham']
# (['pepperoni', 'anchovy', 'ham'], [])
# []
# (['pepperoni', 'anchovy', 'ham'], [])
# -----
# ['ham']
# (['ham'], ['mushroom'], ['pepperoni', 'mushroom'], ['mushroom', 'ham', 'pepperoni'])
# ['mushroom']
# (['ham'], ['mushroom'], ['pepperoni', 'mushroom'], ['mushroom', 'ham', 'pepperoni'])
# ['pepperoni', 'mushroom']
# (['ham'], ['mushroom'], ['pepperoni', 'mushroom'], ['mushroom', 'ham', 'pepperoni'])
# ['mushroom', 'ham', 'pepperoni']
# (['ham'], ['mushroom'], ['pepperoni', 'mushroom'], ['mushroom', 'ham', 'pepperoni'])
# -----
# []
# ([], ['ham'])
# ['ham']
# ([], ['ham'])
# -----
# ['mushroom', 'olive']
# (['mushroom', 'olive'],)
# -----
# []
# ([], [], ['olive', 'olive', 'pepperoni'], ['olive', 'ham'])
# []
# ([], [], ['olive', 'olive', 'pepperoni'], ['olive', 'ham'])
# ['olive', 'olive', 'pepperoni']
# ([], [], ['olive', 'olive', 'pepperoni'], ['olive', 'ham'])
# ['olive', 'ham']
# ([], [], ['olive', 'olive', 'pepperoni'], ['olive', 'ham'])
# -----
# ['mushroom']
# (['mushroom'], ['ham'], [])
# ['ham']
# (['mushroom'], ['ham'], [])
# []
# (['mushroom'], ['ham'], [])
# -----
# ['pepperoni', 'olive', 'olive']
# (['pepperoni', 'olive', 'olive'], [], ['anchovy'])
# []
# (['pepperoni', 'olive', 'olive'], [], ['anchovy'])
# ['anchovy']
# (['pepperoni', 'olive', 'olive'], [], ['anchovy'])
# -----
# ['mushroom', 'olive']
# (['mushroom', 'olive'], [], [])
# []
# (['mushroom', 'olive'], [], [])
# []
# (['mushroom', 'olive'], [], [])
# -----
# -----
# ['pepperoni', 'anchovy', 'olive']
# (['pepperoni', 'anchovy', 'olive'], ['mushroom', 'olive', 'pepperoni'], ['ham'], ['mushroom'])
# ['mushroom', 'olive', 'pepperoni']
# (['pepperoni', 'anchovy', 'olive'], ['mushroom', 'olive', 'pepperoni'], ['ham'], ['mushroom'])
# ['ham']
# (['pepperoni', 'anchovy', 'olive'], ['mushroom', 'olive', 'pepperoni'], ['ham'], ['mushroom'])
# ['mushroom']
# (['pepperoni', 'anchovy', 'olive'], ['mushroom', 'olive', 'pepperoni'], ['ham'], ['mushroom'])
# -----
# []
# ([],)
# -----
# ['ham', 'anchovy']
# (['ham', 'anchovy'], ['anchovy', 'anchovy', 'olive'])
# ['anchovy', 'anchovy', 'olive']
# (['ham', 'anchovy'], ['anchovy', 'anchovy', 'olive'])
# -----
# ['mushroom', 'olive']
# (['mushroom', 'olive'], ['olive', 'anchovy'], [])
# ['olive', 'anchovy']
# (['mushroom', 'olive'], ['olive', 'anchovy'], [])
# []
# (['mushroom', 'olive'], ['olive', 'anchovy'], [])
# -----
# -----
# ['pepperoni', 'pepperoni', 'pepperoni']
# (['pepperoni', 'pepperoni', 'pepperoni'], ['ham', 'mushroom'])
# ['ham', 'mushroom']
# (['pepperoni', 'pepperoni', 'pepperoni'], ['ham', 'mushroom'])
# -----
# -----
# -----
# ['pepperoni', 'ham', 'anchovy']
# (['pepperoni', 'ham', 'anchovy'], [], [], ['ham', 'ham', 'anchovy'])
# []
# (['pepperoni', 'ham', 'anchovy'], [], [], ['ham', 'ham', 'anchovy'])
# []
# (['pepperoni', 'ham', 'anchovy'], [], [], ['ham', 'ham', 'anchovy'])
# ['ham', 'ham', 'anchovy']
# (['pepperoni', 'ham', 'anchovy'], [], [], ['ham', 'ham', 'anchovy'])
# -----
# ['mushroom', 'anchovy', 'ham']
# (['mushroom', 'anchovy', 'ham'], ['anchovy'])
# ['anchovy']
# (['mushroom', 'anchovy', 'ham'], ['anchovy'])
# -----
# []
# ([],)
# -----
# ['olive']
# (['olive'], ['olive'], ['mushroom', 'olive', 'mushroom'], ['olive', 'ham', 'ham'])
# ['olive']
# (['olive'], ['olive'], ['mushroom', 'olive', 'mushroom'], ['olive', 'ham', 'ham'])
# ['mushroom', 'olive', 'mushroom']
# (['olive'], ['olive'], ['mushroom', 'olive', 'mushroom'], ['olive', 'ham', 'ham'])
# ['olive', 'ham', 'ham']
# (['olive'], ['olive'], ['mushroom', 'olive', 'mushroom'], ['olive', 'ham', 'ham'])
# -----
# -----
# ['pepperoni', 'olive']
# (['pepperoni', 'olive'], ['anchovy'], ['pepperoni', 'pepperoni', 'olive'])
# ['anchovy']
# (['pepperoni', 'olive'], ['anchovy'], ['pepperoni', 'pepperoni', 'olive'])
# ['pepperoni', 'pepperoni', 'olive']
# (['pepperoni', 'olive'], ['anchovy'], ['pepperoni', 'pepperoni', 'olive'])
# -----
# []
# ([], [], ['pepperoni'], ['anchovy', 'pepperoni'])
# []
# ([], [], ['pepperoni'], ['anchovy', 'pepperoni'])
# ['pepperoni']
# ([], [], ['pepperoni'], ['anchovy', 'pepperoni'])
# ['anchovy', 'pepperoni']
# ([], [], ['pepperoni'], ['anchovy', 'pepperoni'])
# -----
# []
# ([], ['pepperoni', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'])
# ['pepperoni', 'anchovy', 'mushroom']
# ([], ['pepperoni', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'])
# []
# ([], ['pepperoni', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'])
# ['mushroom', 'ham']
# ([], ['pepperoni', 'anchovy', 'mushroom'], [], ['mushroom', 'ham'])
# -----
# ['ham', 'ham']
# (['ham', 'ham'], ['pepperoni', 'mushroom', 'olive'], ['ham', 'olive'])
# ['pepperoni', 'mushroom', 'olive']
# (['ham', 'ham'], ['pepperoni', 'mushroom', 'olive'], ['ham', 'olive'])
# ['ham', 'olive']
# (['ham', 'ham'], ['pepperoni', 'mushroom', 'olive'], ['ham', 'olive'])
# -----
# -----
# ['mushroom']
# (['mushroom'], [], [], ['anchovy', 'ham'])
# []
# (['mushroom'], [], [], ['anchovy', 'ham'])
# []
# (['mushroom'], [], [], ['anchovy', 'ham'])
# ['anchovy', 'ham']
# (['mushroom'], [], [], ['anchovy', 'ham'])
# -----
# []
# ([], ['pepperoni'], ['mushroom', 'mushroom'])
# ['pepperoni']
# ([], ['pepperoni'], ['mushroom', 'mushroom'])
# ['mushroom', 'mushroom']
# ([], ['pepperoni'], ['mushroom', 'mushroom'])
# -----
# []
# ([], ['mushroom'], [])
# ['mushroom']
# ([], ['mushroom'], [])
# []
# ([], ['mushroom'], [])
# -----
# ['olive', 'ham']
# (['olive', 'ham'], ['anchovy', 'olive'])
# ['anchovy', 'olive']
# (['olive', 'ham'], ['anchovy', 'olive'])
# -----
# ['anchovy', 'anchovy', 'pepperoni']
# (['anchovy', 'anchovy', 'pepperoni'], ['ham'], ['olive'])
# ['ham']
# (['anchovy', 'anchovy', 'pepperoni'], ['ham'], ['olive'])
# ['olive']
# (['anchovy', 'anchovy', 'pepperoni'], ['ham'], ['olive'])
# -----
# []
# ([], ['mushroom', 'pepperoni'], ['olive', 'mushroom', 'anchovy'], ['olive', 'anchovy', 'olive'])
# ['mushroom', 'pepperoni']
# ([], ['mushroom', 'pepperoni'], ['olive', 'mushroom', 'anchovy'], ['olive', 'anchovy', 'olive'])
# ['olive', 'mushroom', 'anchovy']
# ([], ['mushroom', 'pepperoni'], ['olive', 'mushroom', 'anchovy'], ['olive', 'anchovy', 'olive'])
# ['olive', 'anchovy', 'olive']
# ([], ['mushroom', 'pepperoni'], ['olive', 'mushroom', 'anchovy'], ['olive', 'anchovy', 'olive'])
# -----
# []
# ([], ['ham'], ['ham', 'anchovy'], ['pepperoni', 'anchovy'])
# ['ham']
# ([], ['ham'], ['ham', 'anchovy'], ['pepperoni', 'anchovy'])
# ['ham', 'anchovy']
# ([], ['ham'], ['ham', 'anchovy'], ['pepperoni', 'anchovy'])
# ['pepperoni', 'anchovy']
# ([], ['ham'], ['ham', 'anchovy'], ['pepperoni', 'anchovy'])
# -----
# ['olive', 'ham', 'anchovy']
# (['olive', 'ham', 'anchovy'], ['ham'], ['olive', 'ham', 'ham'])
# ['ham']
# (['olive', 'ham', 'anchovy'], ['ham'], ['olive', 'ham', 'ham'])
# ['olive', 'ham', 'ham']
# (['olive', 'ham', 'anchovy'], ['ham'], ['olive', 'ham', 'ham'])
# -----
# ['olive', 'anchovy', 'mushroom']
# (['olive', 'anchovy', 'mushroom'],)
# -----
# ['anchovy']
# (['anchovy'],)
# -----
# -----
# []
# ([],)
# -----
# -----
# -----
# ['ham']
# (['ham'], ['anchovy', 'anchovy'])
# ['anchovy', 'anchovy']
# (['ham'], ['anchovy', 'anchovy'])
# -----
# ['ham', 'pepperoni', 'ham']
# (['ham', 'pepperoni', 'ham'], ['ham'], ['ham', 'pepperoni', 'anchovy'])
# ['ham']
# (['ham', 'pepperoni', 'ham'], ['ham'], ['ham', 'pepperoni', 'anchovy'])
# ['ham', 'pepperoni', 'anchovy']
# (['ham', 'pepperoni', 'ham'], ['ham'], ['ham', 'pepperoni', 'anchovy'])
# -----
# -----
# ['anchovy', 'pepperoni']
# (['anchovy', 'pepperoni'],)
# -----
# ['pepperoni', 'ham', 'pepperoni']
# (['pepperoni', 'ham', 'pepperoni'], ['ham'])
# ['ham']
# (['pepperoni', 'ham', 'pepperoni'], ['ham'])
# -----
# ['mushroom']
# (['mushroom'], ['pepperoni', 'ham', 'pepperoni'], [], ['pepperoni', 'anchovy'])
# ['pepperoni', 'ham', 'pepperoni']
# (['mushroom'], ['pepperoni', 'ham', 'pepperoni'], [], ['pepperoni', 'anchovy'])
# []
# (['mushroom'], ['pepperoni', 'ham', 'pepperoni'], [], ['pepperoni', 'anchovy'])
# ['pepperoni', 'anchovy']
# (['mushroom'], ['pepperoni', 'ham', 'pepperoni'], [], ['pepperoni', 'anchovy'])
# -----
# []
# ([],)
# -----
# ['ham']
# (['ham'], ['anchovy', 'mushroom', 'mushroom'], ['anchovy'])
# ['anchovy', 'mushroom', 'mushroom']
# (['ham'], ['anchovy', 'mushroom', 'mushroom'], ['anchovy'])
# ['anchovy']
# (['ham'], ['anchovy', 'mushroom', 'mushroom'], ['anchovy'])
# -----
# ['ham']
# (['ham'], ['pepperoni'], ['olive', 'mushroom'])
# ['pepperoni']
# (['ham'], ['pepperoni'], ['olive', 'mushroom'])
# ['olive', 'mushroom']
# (['ham'], ['pepperoni'], ['olive', 'mushroom'])
# -----
# ['mushroom', 'pepperoni', 'anchovy']
# (['mushroom', 'pepperoni', 'anchovy'], ['ham', 'mushroom', 'anchovy'], [])
# ['ham', 'mushroom', 'anchovy']
# (['mushroom', 'pepperoni', 'anchovy'], ['ham', 'mushroom', 'anchovy'], [])
# []
# (['mushroom', 'pepperoni', 'anchovy'], ['ham', 'mushroom', 'anchovy'], [])
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'], ['mushroom', 'anchovy', 'mushroom'])
# ['mushroom', 'anchovy', 'mushroom']
# (['olive', 'mushroom'], ['mushroom', 'anchovy', 'mushroom'])
# -----
# ['olive', 'mushroom']
# (['olive', 'mushroom'], ['olive'], ['anchovy', 'olive', 'olive'])
# ['olive']
# (['olive', 'mushroom'], ['olive'], ['anchovy', 'olive', 'olive'])
# ['anchovy', 'olive', 'olive']
# (['olive', 'mushroom'], ['olive'], ['anchovy', 'olive', 'olive'])
# -----
# -----
# []
# ([], ['anchovy'], [], ['mushroom', 'ham'])
# ['anchovy']
# ([], ['anchovy'], [], ['mushroom', 'ham'])
# []
# ([], ['anchovy'], [], ['mushroom', 'ham'])
# ['mushroom', 'ham']
# ([], ['anchovy'], [], ['mushroom', 'ham'])
# -----
# ['mushroom', 'olive']
# (['mushroom', 'olive'], ['olive'], ['olive', 'pepperoni'])
# ['olive']
# (['mushroom', 'olive'], ['olive'], ['olive', 'pepperoni'])
# ['olive', 'pepperoni']
# (['mushroom', 'olive'], ['olive'], ['olive', 'pepperoni'])
# -----
# -----
# -----
# []
# ([], ['olive', 'pepperoni', 'olive'])
# ['olive', 'pepperoni', 'olive']
# ([], ['olive', 'pepperoni', 'olive'])
# -----
# []
# ([], ['pepperoni', 'olive'], ['olive', 'mushroom'])
# ['pepperoni', 'olive']
# ([], ['pepperoni', 'olive'], ['olive', 'mushroom'])
# ['olive', 'mushroom']
# ([], ['pepperoni', 'olive'], ['olive', 'mushroom'])
# -----
# ['olive']
# (['olive'],)
# -----
# ['pepperoni', 'olive', 'pepperoni']
# (['pepperoni', 'olive', 'pepperoni'], ['anchovy'])
# ['anchovy']
# (['pepperoni', 'olive', 'pepperoni'], ['anchovy'])
# -----
# ['anchovy']
# (['anchovy'],)
# -----
# ['olive']
# (['olive'], ['pepperoni', 'ham'], ['mushroom'])
# ['pepperoni', 'ham']
# (['olive'], ['pepperoni', 'ham'], ['mushroom'])
# ['mushroom']
# (['olive'], ['pepperoni', 'ham'], ['mushroom'])
# -----
# []
# ([], [], ['ham'])
# []
# ([], [], ['ham'])
# ['ham']
# ([], [], ['ham'])
# -----
# -----
# -----
# ['ham', 'pepperoni', 'mushroom']
# (['ham', 'pepperoni', 'mushroom'], [], [], [])
# []
# (['ham', 'pepperoni', 'mushroom'], [], [], [])
# []
# ...
# -----
# ['pepperoni']
# (['pepperoni'], ['anchovy'], ['mushroom', 'mushroom'])
# ['anchovy']
# (['pepperoni'], ['anchovy'], ['mushroom', 'mushroom'])
# ['mushroom', 'mushroom']
# (['pepperoni'], ['anchovy'], ['mushroom', 'mushroom'])
# -----
# -----
# ['pepperoni']
# (['pepperoni'], ['pepperoni', 'mushroom'], ['pepperoni', 'anchovy'], ['olive', 'mushroom', 'pepperoni'])
# ['pepperoni', 'mushroom']
# (['pepperoni'], ['pepperoni', 'mushroom'], ['pepperoni', 'anchovy'], ['olive', 'mushroom', 'pepperoni'])
# ['pepperoni', 'anchovy']
# (['pepperoni'], ['pepperoni', 'mushroom'], ['pepperoni', 'anchovy'], ['olive', 'mushroom', 'pepperoni'])
# ['olive', 'mushroom', 'pepperoni']
# (['pepperoni'], ['pepperoni', 'mushroom'], ['pepperoni', 'anchovy'], ['olive', 'mushroom', 'pepperoni'])
# -----
# ['ham', 'ham']
# (['ham', 'ham'], [], ['olive'], ['pepperoni'])
# []
# (['ham', 'ham'], [], ['olive'], ['pepperoni'])
# ['olive']
# (['ham', 'ham'], [], ['olive'], ['pepperoni'])
# ['pepperoni']
# (['ham', 'ham'], [], ['olive'], ['pepperoni'])
# -----
# []
# ([], ['ham', 'ham', 'anchovy'], ['mushroom', 'pepperoni', 'olive'])
# ['ham', 'ham', 'anchovy']
# ([], ['ham', 'ham', 'anchovy'], ['mushroom', 'pepperoni', 'olive'])
# ['mushroom', 'pepperoni', 'olive']
# ([], ['ham', 'ham', 'anchovy'], ['mushroom', 'pepperoni', 'olive'])
# -----
# []
# ([], ['pepperoni'], ['mushroom'], ['anchovy'])
# ['pepperoni']
# ([], ['pepperoni'], ['mushroom'], ['anchovy'])
# ['mushroom']
# ([], ['pepperoni'], ['mushroom'], ['anchovy'])
# ['anchovy']
# ([], ['pepperoni'], ['mushroom'], ['anchovy'])
# -----
# ['olive']
# (['olive'], ['anchovy'], [], ['ham', 'pepperoni', 'anchovy'])
# ['anchovy']
# (['olive'], ['anchovy'], [], ['ham', 'pepperoni', 'anchovy'])
# []
# (['olive'], ['anchovy'], [], ['ham', 'pepperoni', 'anchovy'])
# ['ham', 'pepperoni', 'anchovy']
# (['olive'], ['anchovy'], [], ['ham', 'pepperoni', 'anchovy'])
# -----
# []
# ([], [])
# []
# ([], [])
# -----
# []
# ([], ['anchovy', 'mushroom'], [])
# ['anchovy', 'mushroom']
# ([], ['anchovy', 'mushroom'], [])
# []
# ([], ['anchovy', 'mushroom'], [])
# -----
# ['ham', 'pepperoni']
# (['ham', 'pepperoni'], ['ham', 'pepperoni', 'pepperoni'], [])
# ['ham', 'pepperoni', 'pepperoni']
# (['ham', 'pepperoni'], ['ham', 'pepperoni', 'pepperoni'], [])
# []
# (['ham', 'pepperoni'], ['ham', 'pepperoni', 'pepperoni'], [])
# -----
# -----
# ['ham']
# (['ham'], ['olive'], ['olive', 'olive'], ['mushroom'])
# ['olive']
# (['ham'], ['olive'], ['olive', 'olive'], ['mushroom'])
# ['olive', 'olive']
# (['ham'], ['olive'], ['olive', 'olive'], ['mushroom'])
# ['mushroom']
# (['ham'], ['olive'], ['olive', 'olive'], ['mushroom'])
# -----
# ['mushroom', 'ham']
# (['mushroom', 'ham'], ['anchovy'])
# ['anchovy']
# (['mushroom', 'ham'], ['anchovy'])
# -----
# ['anchovy', 'olive', 'mushroom']
# (['anchovy', 'olive', 'mushroom'], ['anchovy'], ['mushroom', 'olive', 'olive'])
# ['anchovy']
# (['anchovy', 'olive', 'mushroom'], ['anchovy'], ['mushroom', 'olive', 'olive'])
# ['mushroom', 'olive', 'olive']
# (['anchovy', 'olive', 'mushroom'], ['anchovy'], ['mushroom', 'olive', 'olive'])
# -----
# -----
# -----
# ['pepperoni', 'pepperoni', 'ham']
# (['pepperoni', 'pepperoni', 'ham'],)
# -----
# ['mushroom']
# (['mushroom'],)
# -----
# ['anchovy', 'olive']
# (['anchovy', 'olive'], ['pepperoni', 'mushroom', 'pepperoni'])
# ['pepperoni', 'mushroom', 'pepperoni']
# (['anchovy', 'olive'], ['pepperoni', 'mushroom', 'pepperoni'])
# -----
# ['mushroom', 'anchovy', 'olive']
# (['mushroom', 'anchovy', 'olive'], [], ['ham'])
# []
# (['mushroom', 'anchovy', 'olive'], [], ['ham'])
# ['ham']
# (['mushroom', 'anchovy', 'olive'], [], ['ham'])
# -----
# []
# ([], ['pepperoni'])
# ['pepperoni']
# ([], ['pepperoni'])
# -----
# -----
# ['anchovy', 'olive', 'mushroom']
# (['anchovy', 'olive', 'mushroom'], ['ham'], ['anchovy', 'ham'], ['mushroom'])
# ['ham']
# (['anchovy', 'olive', 'mushroom'], ['ham'], ['anchovy', 'ham'], ['mushroom'])
# ['anchovy', 'ham']
# (['anchovy', 'olive', 'mushroom'], ['ham'], ['anchovy', 'ham'], ['mushroom'])
# ['mushroom']
# (['anchovy', 'olive', 'mushroom'], ['ham'], ['anchovy', 'ham'], ['mushroom'])
# -----
# []
# ([], ['anchovy'], ['mushroom', 'anchovy'], ['olive', 'olive', 'olive'])
# ['anchovy']
# ([], ['anchovy'], ['mushroom', 'anchovy'], ['olive', 'olive', 'olive'])
# ['mushroom', 'anchovy']
# ([], ['anchovy'], ['mushroom', 'anchovy'], ['olive', 'olive', 'olive'])
# ['olive', 'olive', 'olive']
# ([], ['anchovy'], ['mushroom', 'anchovy'], ['olive', 'olive', 'olive'])
# -----
# ['olive', 'ham']
# (['olive', 'ham'],)
# -----
# ['olive']
# (['olive'], ['mushroom', 'mushroom', 'mushroom'])
# ['mushroom', 'mushroom', 'mushroom']
# (['olive'], ['mushroom', 'mushroom', 'mushroom'])
# -----
# ['anchovy']
# (['anchovy'], ['anchovy', 'anchovy'], ['olive', 'olive'])
# ['anchovy', 'anchovy']
# (['anchovy'], ['anchovy', 'anchovy'], ['olive', 'olive'])
# ['olive', 'olive']
# (['anchovy'], ['anchovy', 'anchovy'], ['olive', 'olive'])
# -----
# ['ham', 'ham', 'mushroom']
# (['ham', 'ham', 'mushroom'],)
# -----
# []
# ([], ['pepperoni'], ['anchovy'], ['anchovy', 'mushroom'])
# ['pepperoni']
# ([], ['pepperoni'], ['anchovy'], ['anchovy', 'mushroom'])
# ['anchovy']
# ([], ['pepperoni'], ['anchovy'], ['anchovy', 'mushroom'])
# ['anchovy', 'mushroom']
# ([], ['pepperoni'], ['anchovy'], ['anchovy', 'mushroom'])
# -----
# ['anchovy', 'anchovy', 'ham']
# (['anchovy', 'anchovy', 'ham'], ['ham', 'pepperoni'], ['mushroom', 'mushroom'])
# ['ham', 'pepperoni']
# (['anchovy', 'anchovy', 'ham'], ['ham', 'pepperoni'], ['mushroom', 'mushroom'])
# ['mushroom', 'mushroom']
# (['anchovy', 'anchovy', 'ham'], ['ham', 'pepperoni'], ['mushroom', 'mushroom'])
# -----
# []
# ([], ['pepperoni', 'pepperoni'], ['olive', 'ham', 'ham'], ['olive', 'ham'])
# ['pepperoni', 'pepperoni']
# ([], ['pepperoni', 'pepperoni'], ['olive', 'ham', 'ham'], ['olive', 'ham'])
# ['olive', 'ham', 'ham']
# ([], ['pepperoni', 'pepperoni'], ['olive', 'ham', 'ham'], ['olive', 'ham'])
# ['olive', 'ham']
# ([], ['pepperoni', 'pepperoni'], ['olive', 'ham', 'ham'], ['olive', 'ham'])
# -----
# ['ham', 'mushroom']
# (['ham', 'mushroom'], ['mushroom', 'ham', 'anchovy'])
# ['mushroom', 'ham', 'anchovy']
# (['ham', 'mushroom'], ['mushroom', 'ham', 'anchovy'])
# -----
# -----
# ['pepperoni']
# (['pepperoni'], ['mushroom'], [])
# ['mushroom']
# (['pepperoni'], ['mushroom'], [])
# []
# (['pepperoni'], ['mushroom'], [])
# -----
# []
# ([],)
# -----
# ['olive', 'mushroom', 'olive']
# (['olive', 'mushroom', 'olive'], ['anchovy', 'ham'], ['pepperoni', 'anchovy'])
# ['anchovy', 'ham']
# (['olive', 'mushroom', 'olive'], ['anchovy', 'ham'], ['pepperoni', 'anchovy'])
# ['pepperoni', 'anchovy']
# (['olive', 'mushroom', 'olive'], ['anchovy', 'ham'], ['pepperoni', 'anchovy'])
# -----
# ['pepperoni', 'mushroom']
# (['pepperoni', 'mushroom'], ['ham'])
# ['ham']
# (['pepperoni', 'mushroom'], ['ham'])
# -----
# ['ham', 'pepperoni']
# (['ham', 'pepperoni'], ['olive'], ['pepperoni'], ['anchovy', 'mushroom'])
# ['olive']
# (['ham', 'pepperoni'], ['olive'], ['pepperoni'], ['anchovy', 'mushroom'])
# ['pepperoni']
# (['ham', 'pepperoni'], ['olive'], ['pepperoni'], ['anchovy', 'mushroom'])
# ['anchovy', 'mushroom']
# (['ham', 'pepperoni'], ['olive'], ['pepperoni'], ['anchovy', 'mushroom'])
# -----
# -----
# -----
# ['ham']
# (['ham'], [])
# []
# (['ham'], [])
# -----
# ['pepperoni', 'pepperoni']
# (['pepperoni', 'pepperoni'], ['ham', 'olive', 'pepperoni'], [])
# ['ham', 'olive', 'pepperoni']
# (['pepperoni', 'pepperoni'], ['ham', 'olive', 'pepperoni'], [])
# []
# (['pepperoni', 'pepperoni'], ['ham', 'olive', 'pepperoni'], [])
# -----
# ['ham', 'olive']
# (['ham', 'olive'], ['pepperoni', 'ham', 'mushroom'], [])
# ['pepperoni', 'ham', 'mushroom']
# (['ham', 'olive'], ['pepperoni', 'ham', 'mushroom'], [])
# []
# (['ham', 'olive'], ['pepperoni', 'ham', 'mushroom'], [])
# -----
# ['pepperoni', 'mushroom']
# (['pepperoni', 'mushroom'], ['anchovy', 'ham', 'anchovy'], ['ham', 'anchovy', 'ham'])
# ['anchovy', 'ham', 'anchovy']
# (['pepperoni', 'mushroom'], ['anchovy', 'ham', 'anchovy'], ['ham', 'anchovy', 'ham'])
# ['ham', 'anchovy', 'ham']
# (['pepperoni', 'mushroom'], ['anchovy', 'ham', 'anchovy'], ['ham', 'anchovy', 'ham'])
# -----
# -----
# ['anchovy']
# (['anchovy'], ['olive', 'ham'], ['olive', 'pepperoni'])
# ['olive', 'ham']
# (['anchovy'], ['olive', 'ham'], ['olive', 'pepperoni'])
# ['olive', 'pepperoni']
# (['anchovy'], ['olive', 'ham'], ['olive', 'pepperoni'])
# -----
# ['olive', 'ham', 'mushroom']
# (['olive', 'ham', 'mushroom'], ['pepperoni'])
# ['pepperoni']
# (['olive', 'ham', 'mushroom'], ['pepperoni'])
# -----
# []
# ([], ['olive', 'anchovy', 'pepperoni'], ['olive', 'olive'], ['ham', 'anchovy'])
# ['olive', 'anchovy', 'pepperoni']
# ([], ['olive', 'anchovy', 'pepperoni'], ['olive', 'olive'], ['ham', 'anchovy'])
# ['olive', 'olive']
# ([], ['olive', 'anchovy', 'pepperoni'], ['olive', 'olive'], ['ham', 'anchovy'])
# ['ham', 'anchovy']
# ([], ['olive', 'anchovy', 'pepperoni'], ['olive', 'olive'], ['ham', 'anchovy'])
# -----
# []
# ([], ['olive', 'pepperoni', 'pepperoni'], ['ham', 'olive'])
# ['olive', 'pepperoni', 'pepperoni']
# ([], ['olive', 'pepperoni', 'pepperoni'], ['ham', 'olive'])
# ['ham', 'olive']
# ([], ['olive', 'pepperoni', 'pepperoni'], ['ham', 'olive'])
# -----
# []
# ([],)
# -----
# ['ham', 'pepperoni']
# (['ham', 'pepperoni'], ['ham'], ['ham'])
# ['ham']
# (['ham', 'pepperoni'], ['ham'], ['ham'])
# ['ham']
# (['ham', 'pepperoni'], ['ham'], ['ham'])
# -----
# ['anchovy', 'pepperoni']
# (['anchovy', 'pepperoni'],)
# -----
# ['olive']
# (['olive'], ['mushroom'], ['anchovy', 'olive', 'anchovy'], [])
# ['mushroom']
# (['olive'], ['mushroom'], ['anchovy', 'olive', 'anchovy'], [])
# ['anchovy', 'olive', 'anchovy']
# (['olive'], ['mushroom'], ['anchovy', 'olive', 'anchovy'], [])
# []
# (['olive'], ['mushroom'], ['anchovy', 'olive', 'anchovy'], [])
# -----
# -----
# ['mushroom']
# (['mushroom'], [], ['ham', 'pepperoni', 'ham'])
# []
# (['mushroom'], [], ['ham', 'pepperoni', 'ham'])
# ['ham', 'pepperoni', 'ham']
# (['mushroom'], [], ['ham', 'pepperoni', 'ham'])
# -----
# []
# ([], [], ['olive', 'ham'])
# []
# ([], [], ['olive', 'ham'])
# ['olive', 'ham']
# ([], [], ['olive', 'ham'])
# -----
# ['anchovy', 'anchovy', 'ham']
# (['anchovy', 'anchovy', 'ham'],)
# -----
# ['olive', 'pepperoni', 'olive']
# (['olive', 'pepperoni', 'olive'], ['ham', 'mushroom'])
# ['ham', 'mushroom']
# (['olive', 'pepperoni', 'olive'], ['ham', 'mushroom'])
# -----
# []
# ([], ['pepperoni', 'ham'], ['ham', 'ham', 'mushroom'])
# ['pepperoni', 'ham']
# ([], ['pepperoni', 'ham'], ['ham', 'ham', 'mushroom'])
# ['ham', 'ham', 'mushroom']
# ([], ['pepperoni', 'ham'], ['ham', 'ham', 'mushroom'])
# -----
# -----
# ['olive', 'anchovy', 'ham']
# (['olive', 'anchovy', 'ham'], ['mushroom', 'olive'], ['mushroom', 'anchovy', 'olive'], ['mushroom', 'pepperoni'])
# ['mushroom', 'olive']
# (['olive', 'anchovy', 'ham'], ['mushroom', 'olive'], ['mushroom', 'anchovy', 'olive'], ['mushroom', 'pepperoni'])
# ['mushroom', 'anchovy', 'olive']
# (['olive', 'anchovy', 'ham'], ['mushroom', 'olive'], ['mushroom', 'anchovy', 'olive'], ['mushroom', 'pepperoni'])
# ['mushroom', 'pepperoni']
# (['olive', 'anchovy', 'ham'], ['mushroom', 'olive'], ['mushroom', 'anchovy', 'olive'], ['mushroom', 'pepperoni'])
# -----
# ['ham', 'anchovy']
# (['ham', 'anchovy'], ['olive', 'olive'], [])
# ['olive', 'olive']
# (['ham', 'anchovy'], ['olive', 'olive'], [])
# []
# (['ham', 'anchovy'], ['olive', 'olive'], [])
# -----
# ['anchovy']
# (['anchovy'],)
# -----
# []
# ([],)
# -----
# ['pepperoni', 'mushroom', 'pepperoni']
# (['pepperoni', 'mushroom', 'pepperoni'], ['anchovy', 'mushroom'])
# ['anchovy', 'mushroom']
# (['pepperoni', 'mushroom', 'pepperoni'], ['anchovy', 'mushroom'])
# -----
# []
# ([], ['anchovy'])
# ['anchovy']
# ([], ['anchovy'])
# -----
# []
# ([], ['mushroom'], ['olive', 'ham', 'pepperoni'])
# ['mushroom']
# ([], ['mushroom'], ['olive', 'ham', 'pepperoni'])
# ['olive', 'ham', 'pepperoni']
# ([], ['mushroom'], ['olive', 'ham', 'pepperoni'])
# -----
# []
# ([], ['mushroom', 'mushroom'])
# ['mushroom', 'mushroom']
# ([], ['mushroom', 'mushroom'])
# -----
# ['ham', 'olive', 'pepperoni']
# (['ham', 'olive', 'pepperoni'], ['ham', 'olive'], [], ['ham', 'ham', 'anchovy'])
# ['ham', 'olive']
# (['ham', 'olive', 'pepperoni'], ['ham', 'olive'], [], ['ham', 'ham', 'anchovy'])
# []
# (['ham', 'olive', 'pepperoni'], ['ham', 'olive'], [], ['ham', 'ham', 'anchovy'])
# ['ham', 'ham', 'anchovy']
# (['ham', 'olive', 'pepperoni'], ['ham', 'olive'], [], ['ham', 'ham', 'anchovy'])
# -----
# -----
# -----
# []
# ([], ['anchovy', 'mushroom'], ['olive', 'anchovy'], ['ham', 'anchovy', 'mushroom'])
# ['anchovy', 'mushroom']
# ([], ['anchovy', 'mushroom'], ['olive', 'anchovy'], ['ham', 'anchovy', 'mushroom'])
# ['olive', 'anchovy']
# ([], ['anchovy', 'mushroom'], ['olive', 'anchovy'], ['ham', 'anchovy', 'mushroom'])
# ['ham', 'anchovy', 'mushroom']
# ([], ['anchovy', 'mushroom'], ['olive', 'anchovy'], ['ham', 'anchovy', 'mushroom'])
# -----
# ['anchovy', 'pepperoni', 'mushroom']
# (['anchovy', 'pepperoni', 'mushroom'],)
# -----
# -----
# []
# ([], [])
# []
# ([], [])
# -----
# ['pepperoni', 'olive']
# (['pepperoni', 'olive'], ['anchovy', 'pepperoni', 'mushroom'], ['olive', 'mushroom', 'mushroom'])
# ['anchovy', 'pepperoni', 'mushroom']
# (['pepperoni', 'olive'], ['anchovy', 'pepperoni', 'mushroom'], ['olive', 'mushroom', 'mushroom'])
# ['olive', 'mushroom', 'mushroom']
# (['pepperoni', 'olive'], ['anchovy', 'pepperoni', 'mushroom'], ['olive', 'mushroom', 'mushroom'])
# -----
# []
# ([], [])
# []
# ([], [])
# -----
# ['anchovy', 'pepperoni', 'anchovy']
# (['anchovy', 'pepperoni', 'anchovy'],)
# -----
# ['ham', 'mushroom', 'pepperoni']
# (['ham', 'mushroom', 'pepperoni'], ['mushroom'], ['pepperoni'])
# ['mushroom']
# (['ham', 'mushroom', 'pepperoni'], ['mushroom'], ['pepperoni'])
# ['pepperoni']
# (['ham', 'mushroom', 'pepperoni'], ['mushroom'], ['pepperoni'])
# -----
# ['anchovy', 'pepperoni', 'pepperoni']
# (['anchovy', 'pepperoni', 'pepperoni'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], ['ham', 'ham', 'anchovy'])
# ['mushroom', 'mushroom']
# (['anchovy', 'pepperoni', 'pepperoni'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], ['ham', 'ham', 'anchovy'])
# ['pepperoni', 'olive']
# (['anchovy', 'pepperoni', 'pepperoni'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], ['ham', 'ham', 'anchovy'])
# ['ham', 'ham', 'anchovy']
# (['anchovy', 'pepperoni', 'pepperoni'], ['mushroom', 'mushroom'], ['pepperoni', 'olive'], ['ham', 'ham', 'anchovy'])
# -----
# -----
# -----
# -----
# ['mushroom', 'olive']
# (['mushroom', 'olive'], ['pepperoni', 'mushroom'])
# ['pepperoni', 'mushroom']
# (['mushroom', 'olive'], ['pepperoni', 'mushroom'])
# -----
# ['anchovy']
# (['anchovy'],)
# -----
# ['ham', 'mushroom', 'mushroom']
# (['ham', 'mushroom', 'mushroom'],)
# -----
# -----
# ['olive']
# (['olive'], ['pepperoni', 'anchovy'], [], [])
# ['pepperoni', 'anchovy']
# (['olive'], ['pepperoni', 'anchovy'], [], [])
# []
# (['olive'], ['pepperoni', 'anchovy'], [], [])
# []
# (['olive'], ['pepperoni', 'anchovy'], [], [])
# -----
# []
# ([], ['mushroom', 'mushroom'], ['anchovy', 'olive'])
# ['mushroom', 'mushroom']
# ([], ['mushroom', 'mushroom'], ['anchovy', 'olive'])
# ['anchovy', 'olive']
# ([], ['mushroom', 'mushroom'], ['anchovy', 'olive'])
# -----
# -----
# ['ham']
# (['ham'], ['mushroom', 'pepperoni'], ['pepperoni'])
# ['mushroom', 'pepperoni']
# (['ham'], ['mushroom', 'pepperoni'], ['pepperoni'])
# ['pepperoni']
# (['ham'], ['mushroom', 'pepperoni'], ['pepperoni'])
# -----
# ['pepperoni']
# (['pepperoni'], ['ham', 'ham'])
# ['ham', 'ham']
# (['pepperoni'], ['ham', 'ham'])
# -----
# ['mushroom', 'mushroom', 'olive']
# (['mushroom', 'mushroom', 'olive'],)
# -----
# []
# ([],)
# -----
# []
# ([], ['anchovy', 'pepperoni', 'ham'], ['olive', 'ham'])
# ['anchovy', 'pepperoni', 'ham']
# ([], ['anchovy', 'pepperoni', 'ham'], ['olive', 'ham'])
# ['olive', 'ham']
# ([], ['anchovy', 'pepperoni', 'ham'], ['olive', 'ham'])
# -----
# -----
# ['mushroom', 'ham']
# (['mushroom', 'ham'], ['pepperoni', 'anchovy', 'pepperoni'], ['mushroom'], [])
# ['pepperoni', 'anchovy', 'pepperoni']
# (['mushroom', 'ham'], ['pepperoni', 'anchovy', 'pepperoni'], ['mushroom'], [])
# ['mushroom']
# (['mushroom', 'ham'], ['pepperoni', 'anchovy', 'pepperoni'], ['mushroom'], [])
# []
# (['mushroom', 'ham'], ['pepperoni', 'anchovy', 'pepperoni'], ['mushroom'], [])
# -----
# ['olive']
# (['olive'], [], ['pepperoni'])
# []
# (['olive'], [], ['pepperoni'])
# ['pepperoni']
# (['olive'], [], ['pepperoni'])
# -----
# []
# ([],)
# -----
# -----
#
# ============================== ALL TESTS PASSED! ===============================
# Your submission code: bw376a5897c31ca763c949f9e3e3b48926ae5e8e0dfb0210f3f59d4485
# ================================================================================
